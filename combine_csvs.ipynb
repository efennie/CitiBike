# %%
#create dependencies
import pandas as pd
import csv

# %%
# Read citibike dada and store into Pandas data frame
csv_path = "/Users/bitty/Downloads/JC-202002-citibike-tripdata.csv"
feb2020 = pd.read_csv(csv_path)
feb2020.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           841  2020-02-01 00:02:13.7650  2020-02-01 00:16:15.4720
# 1           206  2020-02-01 00:16:11.3850  2020-02-01 00:19:37.4460
# 2           859  2020-02-01 00:23:22.1090  2020-02-01 00:37:41.5060
# 3           693  2020-02-01 00:25:14.5170  2020-02-01 00:36:48.0280
# 4          1473  2020-02-01 00:32:30.5050  2020-02-01 00:57:04.3740
#
#    start station id  start station name  start station latitude  \
# 0              3199        Newport Pkwy               40.728745
# 1              3273        Manila & 1st               40.721651
# 2              3185           City Hall               40.717733
# 3              3185           City Hall               40.717733
# 4              3192  Liberty Light Rail               40.711242
#
#    start station longitude  end station id         end station name  \
# 0               -74.032108            3213           Van Vorst Park
# ...

# %%
# Read citibike dada and store into Pandas data frame
csv_path = "/Users/bitty/Downloads/JC-202003-citibike-tripdata.csv"
mar2020 = pd.read_csv(csv_path)
mar2020.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           389  2020-03-01 00:14:07.0000  2020-03-01 00:20:36.0880
# 1           242  2020-03-01 00:48:06.4390  2020-03-01 00:52:08.9870
# 2           124  2020-03-01 01:08:46.4880  2020-03-01 01:10:51.2780
# 3           104  2020-03-01 01:22:35.4790  2020-03-01 01:24:20.2470
# 4           228  2020-03-01 01:39:20.2680  2020-03-01 01:43:09.1380
#
#    start station id start station name  start station latitude  \
# 0              3202       Newport PATH               40.727224
# 1              3185          City Hall               40.717733
# 2              3272       Jersey & 3rd               40.723332
# 3              3202       Newport PATH               40.727224
# 4              3194    McGinley Square               40.725340
#
#    start station longitude  end station id   end station name  \
# 0               -74.033759            3203      Hamilton Park
# ...

# %%
# Read citibike dada and store into Pandas data frame
csv_path = "/Users/bitty/Downloads/JC-202004-citibike-tripdata.csv"
apr2020 = pd.read_csv(csv_path)
apr2020.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1437  2020-04-01 01:06:20.6300  2020-04-01 01:30:17.9680
# 1           264  2020-04-01 05:02:42.0570  2020-04-01 05:07:06.1260
# 2           254  2020-04-01 06:20:28.1190  2020-04-01 06:24:42.1380
# 3           429  2020-04-01 06:33:30.5170  2020-04-01 06:40:40.1990
# 4           805  2020-04-01 06:38:32.9220  2020-04-01 06:51:58.2050
#
#    start station id start station name  start station latitude  \
# 0              3678      Fairmount Ave               40.725726
# 1              3207        Oakland Ave               40.737604
# 2              3678      Fairmount Ave               40.725726
# 3              3195            Sip Ave               40.730897
# 4              3193       Lincoln Park               40.724605
#
#    start station longitude  end station id end station name  \
# 0               -74.071959            3678    Fairmount Ave
# ...

# %%
# Read citibike dada and store into Pandas data frame
csv_path = "/Users/bitty/Downloads/JC-202005-citibike-tripdata.csv"
may2020 = pd.read_csv(csv_path)
may2020.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           349  2020-05-01 00:09:45.5860  2020-05-01 00:15:35.2930
# 1           138  2020-05-01 01:11:22.5280  2020-05-01 01:13:41.2460
# 2           229  2020-05-01 05:31:29.5350  2020-05-01 05:35:19.2400
# 3           261  2020-05-01 05:51:39.3960  2020-05-01 05:56:00.9370
# 4           168  2020-05-01 06:06:31.9510  2020-05-01 06:09:20.1410
#
#    start station id          start station name  start station latitude  \
# 0              3195                     Sip Ave               40.730897
# 1              3792  Columbus Dr at Exchange Pl               40.716870
# 2              3483               Montgomery St               40.719420
# 3              3278            Monmouth and 6th               40.725685
# 4              3194             McGinley Square               40.725340
#
#    start station longitude  end station id end station name  \
# ...

# %%
# Read citibike dada and store into Pandas data frame
csv_path = "/Users/bitty/Downloads/JC-202006-citibike-tripdata.csv"
june2020 = pd.read_csv(csv_path)
june2020.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           122  2020-06-01 00:02:21.7500  2020-06-01 00:04:24.3250
# 1          1282  2020-06-01 00:12:27.1090  2020-06-01 00:33:50.0540
# 2           186  2020-06-01 01:19:59.2090  2020-06-01 01:23:05.8930
# 3           131  2020-06-01 01:26:42.2050  2020-06-01 01:28:53.8040
# 4           266  2020-06-01 01:27:33.7090  2020-06-01 01:32:00.1890
#
#    start station id          start station name  start station latitude  \
# 0              3792  Columbus Dr at Exchange Pl               40.716870
# 1              3198            Heights Elevator               40.748716
# 2              3275              Columbus Drive               40.718355
# 3              3267                Morris Canal               40.712419
# 4              3639                  Harborside               40.719252
#
#    start station longitude  end station id  end station name  \
# ...

# %%
# Read citibike dada and store into Pandas data frame
csv_path = "/Users/bitty/Downloads/JC-202007-citibike-tripdata.csv"
jul2020 = pd.read_csv(csv_path)
jul2020.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          2333  2020-07-01 00:23:19.8220  2020-07-01 01:02:13.2980
# 1          1203  2020-07-01 00:27:45.2420  2020-07-01 00:47:49.1960
# 2           786  2020-07-01 00:34:17.8680  2020-07-01 00:47:24.6310
# 3          1488  2020-07-01 00:51:07.5310  2020-07-01 01:15:56.0200
# 4          2682  2020-07-01 00:51:16.3880  2020-07-01 01:35:58.4590
#
#    start station id          start station name  start station latitude  \
# 0              3694              Jackson Square               40.711130
# 1              3791  Hoboken Ave at Monmouth St               40.735208
# 2              3792  Columbus Dr at Exchange Pl               40.716870
# 3              3677                Glenwood Ave               40.727551
# 4              3191                    Union St               40.718211
#
#    start station longitude  end station id       end station name  \
# ...

# %%
# Read citibike dada and store into Pandas data frame
csv_path = "/Users/bitty/Downloads/JC-202008-citibike-tripdata.csv"
aug2020 = pd.read_csv(csv_path)
aug2020.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           561  2020-08-01 00:00:16.5960  2020-08-01 00:09:38.5610
# 1           236  2020-08-01 00:00:46.3900  2020-08-01 00:04:42.8890
# 2           384  2020-08-01 00:02:38.9250  2020-08-01 00:09:03.7590
# 3          1302  2020-08-01 00:03:27.0270  2020-08-01 00:25:09.2120
# 4          5561  2020-08-01 00:03:57.4810  2020-08-01 01:36:38.5000
#
#    start station id start station name  start station latitude  \
# 0              3185          City Hall               40.717733
# 1              3186      Grove St PATH               40.719586
# 2              3186      Grove St PATH               40.719586
# 3              3185          City Hall               40.717733
# 4              3185          City Hall               40.717733
#
#    start station longitude  end station id end station name  \
# 0               -74.043845            3185        City Hall
# ...
